# %%
import pandas as pd

# %%
pip install openpyxl
# Out:
# ...
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached et_xmlfile-1.1.0-py3-none-any.whl.metadata (1.8 kB)
# Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Using cached et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df_excel = pd.read_excel("관서별 5대범죄 발생 및 검거.xlsx")

df_excel
# Out:
#      관서명  소계(발생)  소계(검거)  살인(발생)  살인(검거)  강도(발생)  강도(검거)  강간(발생)  강간(검거)  \
# 0      계  126401   82680     163     156     276     257    5449    5069
# 1    중부서    2860    1716       2       2       3       2     105      65
# 2    종로서    2472    1589       3       3       6       5     115      98
# 3   남대문서    2094    1226       1       0       6       4      65      46
# 4   서대문서    4029    2579       2       2       5       4     154     124
# 5    혜화서    2233    1354       3       2       5       4      96      63
# 6    용산서    3820    2483       5       5      14      14     194     173
# 7    성북서    2237    1498       2       2       2       1      86      71
# 8   동대문서    4720    3205       5       5      13      13     173     146
# 9    마포서    5854    3597       8       8      14      10     294     247
# 10  영등포서    6867    4154      14      12      22      20     295     183
# 11   성동서    3358    2123       4       4       9       8     126     119
# ...

# %%
gu_dict = {
    '강남서': '강남구', '강동서': '강동구', '강북서': '강북구',
    '강서서': '강서구', '관악서': '관악구', '광진서': '광진구',
    '구로서': '구로구', '금천서': '금천구', '노원서': '노원구',
    '도봉서': '도봉구', '동대문서': '동대문구', '동작서': '동작구',
    '마포서': '마포구', '서대문서': '서대문구', '서초서' : '서초구',
    '성동서': '성동구', '성북서': '성북구', '송파서': '송파구',
    '양천서': '양천구', '영등포서': '영등포구', '용산서': '용산구',
    '은평서': '은평구', '종로서': '종로구', '중부서': '중구', '중랑서': '중랑구'}

# %%
df_excel['구별'] = df_excel['관서명'].map(gu_dict)

# %%
df_excel
# Out:
#      관서명  소계(발생)  소계(검거)  살인(발생)  살인(검거)  강도(발생)  강도(검거)  강간(발생)  강간(검거)  \
# 0      계  126401   82680     163     156     276     257    5449    5069
# 1    중부서    2860    1716       2       2       3       2     105      65
# 2    종로서    2472    1589       3       3       6       5     115      98
# 3   남대문서    2094    1226       1       0       6       4      65      46
# 4   서대문서    4029    2579       2       2       5       4     154     124
# 5    혜화서    2233    1354       3       2       5       4      96      63
# 6    용산서    3820    2483       5       5      14      14     194     173
# 7    성북서    2237    1498       2       2       2       1      86      71
# 8   동대문서    4720    3205       5       5      13      13     173     146
# 9    마포서    5854    3597       8       8      14      10     294     247
# 10  영등포서    6867    4154      14      12      22      20     295     183
# 11   성동서    3358    2123       4       4       9       8     126     119
# ...

# %%
df_excel = df_excel.fillna('구 없음')

# %%
df_excel
# Out:
#      관서명  소계(발생)  소계(검거)  살인(발생)  살인(검거)  강도(발생)  강도(검거)  강간(발생)  강간(검거)  \
# 0      계  126401   82680     163     156     276     257    5449    5069
# 1    중부서    2860    1716       2       2       3       2     105      65
# 2    종로서    2472    1589       3       3       6       5     115      98
# 3   남대문서    2094    1226       1       0       6       4      65      46
# 4   서대문서    4029    2579       2       2       5       4     154     124
# 5    혜화서    2233    1354       3       2       5       4      96      63
# 6    용산서    3820    2483       5       5      14      14     194     173
# 7    성북서    2237    1498       2       2       2       1      86      71
# 8   동대문서    4720    3205       5       5      13      13     173     146
# 9    마포서    5854    3597       8       8      14      10     294     247
# 10  영등포서    6867    4154      14      12      22      20     295     183
# 11   성동서    3358    2123       4       4       9       8     126     119
# ...

# %%
pivot_df = pd.pivot_table(
df_excel,
index=['구별'],
aggfunc='sum'
)

# %%
pivot_df
# Out:
#       강간(검거)  강간(발생)  강도(검거)  강도(발생)                   관서명  살인(검거)  살인(발생)  \
# 구별
# 강남구      225     300      12      15                   강남서       3       3
# 강동구      123     156       8       6                   강동서       3       4
# 강북구      126     153      13      14                   강북서       8       7
# 강서구      191     262      13      13                   강서서       8       7
# 관악구      221     320      14      12                   관악서       8       9
# 광진구      220     240      26      14                   광진서       4       4
# 구 없음    5470    5952     276     299  계남대문서혜화서서부서종암서방배서수서서     172     183
# 구로구      164     281      11      15                   구로서       6       8
# 금천구      122     151       6       6                   금천서       4       3
# 노원구      121     197       7       7                   노원서      10      10
# 도봉구      106     102      10       9                   도봉서       3       3
# ...

# %%
pivot_df = pivot_df.drop('관서명', axis=1)

# %%
pivot_df
# Out:
#       강간(검거)  강간(발생)  강도(검거)  강도(발생)  살인(검거)  살인(발생)  소계(검거)  소계(발생)  절도(검거)  \
# 구별
# 강남구      225     300      12      15       3       3    3370    5194     984
# 강동구      123     156       8       6       3       4    3171    5244     789
# 강북구      126     153      13      14       8       7    3113    4257     618
# 강서구      191     262      13      13       8       7    4190    5585    1260
# 관악구      221     320      14      12       8       9    3712    6345     827
# 광진구      220     240      26      14       4       4    3707    5909    1277
# 구 없음    5470    5952     276     299     172     183   90982  139414   24125
# 구로구      164     281      11      15       6       8    3502    5646     889
# 금천구      122     151       6       6       4       3    2796    3781     888
# 노원구      121     197       7       7      10      10    3268    5130     801
# 도봉구      106     102      10       9       3       3    1900    2664     478
# ...

# %%
pivot_df = pivot_df.drop(index='구 없음')

# %%
pivot_df
# Out:
#       강간(검거)  강간(발생)  강도(검거)  강도(발생)  살인(검거)  살인(발생)  소계(검거)  소계(발생)  절도(검거)  \
# 구별
# 강남구      225     300      12      15       3       3    3370    5194     984
# 강동구      123     156       8       6       3       4    3171    5244     789
# 강북구      126     153      13      14       8       7    3113    4257     618
# 강서구      191     262      13      13       8       7    4190    5585    1260
# 관악구      221     320      14      12       8       9    3712    6345     827
# 광진구      220     240      26      14       4       4    3707    5909    1277
# 구로구      164     281      11      15       6       8    3502    5646     889
# 금천구      122     151       6       6       4       3    2796    3781     888
# 노원구      121     197       7       7      10      10    3268    5130     801
# 도봉구      106     102      10       9       3       3    1900    2664     478
# 동대문구     146     173      13      13       5       5    3205    4720     814
# ...

# %%
pivot_df['강간검거율'] = (pivot_df['강간(검거)'] / pivot_df['강간(발생)']) * 100
pivot_df['강도검거율'] = (pivot_df['강도(검거)'] / pivot_df['강도(발생)']) * 100
pivot_df['살인검거율'] = (pivot_df['살인(검거)'] / pivot_df['살인(발생)']) * 100
pivot_df['절도검거율'] = (pivot_df['절도(검거)'] / pivot_df['절도(발생)']) * 100
pivot_df['폭력검거율'] = (pivot_df['폭력(검거)'] / pivot_df['폭력(발생)']) * 100
pivot_df['검거율'] = ((pivot_df['강간(검거)'] + pivot_df['강도(검거)'] + pivot_df['살인(검거)'] + pivot_df['절도(검거)'] + pivot_df['폭력(검거)']) /
                       (pivot_df['강간(발생)'] + pivot_df['강도(발생)'] + pivot_df['살인(발생)'] + pivot_df['절도(발생)'] + pivot_df['폭력(발생)'])) * 100

# %%
pivot_df
# Out:
#       강간(검거)  강간(발생)  강도(검거)  강도(발생)  살인(검거)  살인(발생)  소계(검거)  소계(발생)  절도(검거)  \
# 구별
# 강남구      225     300      12      15       3       3    3370    5194     984
# 강동구      123     156       8       6       3       4    3171    5244     789
# 강북구      126     153      13      14       8       7    3113    4257     618
# 강서구      191     262      13      13       8       7    4190    5585    1260
# 관악구      221     320      14      12       8       9    3712    6345     827
# 광진구      220     240      26      14       4       4    3707    5909    1277
# 구로구      164     281      11      15       6       8    3502    5646     889
# 금천구      122     151       6       6       4       3    2796    3781     888
# 노원구      121     197       7       7      10      10    3268    5130     801
# 도봉구      106     102      10       9       3       3    1900    2664     478
# 동대문구     146     173      13      13       5       5    3205    4720     814
# ...

# %%
del pivot_df['강도(검거)']
del pivot_df['살인(검거)']
del pivot_df['절도(검거)']
del pivot_df['폭력(검거)']
del pivot_df['소계(발생)']
del pivot_df['소계(검거)']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\kjml\anaconda\envs\pandas_course\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '강도(검거)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[107], line 1
# ----> 1 del pivot_df['강도(검거)']
# ...

# %%
pivot_df
# Out:
#       강간(발생)  강도(발생)  살인(발생)  절도(발생)  폭력(발생)       강간검거율       강도검거율  \
# 구별
# 강남구      300      15       3    2411    2465   75.000000   80.000000
# 강동구      156       6       4    2366    2712   78.846154  133.333333
# 강북구      153      14       7    1434    2649   82.352941   92.857143
# 강서구      262      13       7    2096    3207   72.900763  100.000000
# 관악구      320      12       9    2706    3298   69.062500  116.666667
# 광진구      240      14       4    3026    2625   91.666667  185.714286
# 구로구      281      15       8    2335    3007   58.362989   73.333333
# 금천구      151       6       3    1567    2054   80.794702  100.000000
# 노원구      197       7      10    2193    2723   61.421320  100.000000
# 도봉구      102       9       3    1063    1487  103.921569  111.111111
# 동대문구     173      13       5    1981    2548   84.393064  100.000000
# 동작구      285       9       5    1865    1910   48.771930   55.555556
# ...

# %%
pivot_df_new = pivot_df.rename(columns={'강간(발생)':'강간',
'강도(발생)':'강도',
'살인(발생)':'살인',
'절도(발생)':'절도',
'폭력(발생)':'폭력'})

# %%
pivot_df_new
# Out:
#        강간  강도  살인    절도    폭력       강간검거율       강도검거율       살인검거율      절도검거율  \
# 구별
# 강남구   300  15   3  2411  2465   75.000000   80.000000  100.000000  40.812941
# 강동구   156   6   4  2366  2712   78.846154  133.333333   75.000000  33.347422
# 강북구   153  14   7  1434  2649   82.352941   92.857143  114.285714  43.096234
# 강서구   262  13   7  2096  3207   72.900763  100.000000  114.285714  60.114504
# 관악구   320  12   9  2706  3298   69.062500  116.666667   88.888889  30.561715
# 광진구   240  14   4  3026  2625   91.666667  185.714286  100.000000  42.200925
# 구로구   281  15   8  2335  3007   58.362989   73.333333   75.000000  38.072805
# 금천구   151   6   3  1567  2054   80.794702  100.000000  133.333333  56.668794
# 노원구   197   7  10  2193  2723   61.421320  100.000000  100.000000  36.525308
# 도봉구   102   9   3  1063  1487  103.921569  111.111111  100.000000  44.967074
# 동대문구  173  13   5  1981  2548   84.393064  100.000000  100.000000  41.090358
# ...
